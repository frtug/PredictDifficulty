# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('DATA-FINAL.csv')

# %%
df.tail()
# Out:
#        Termid    RegdNo  Course Grade  CA_100  MTT_50  ETT_100  ETP_100  \
# 65529  318192  15432776  ZVA163    A+    98.0    30.0     46.0      NaN
# 65530  318192  15432776  ZVA164     E    79.0     7.0     29.0      NaN
# 65531  318192  15432776  ZVA165     A    84.0     NaN      NaN     67.0
# 65532  318192  15432776  ZVA167    B+    69.0    20.0     70.0      NaN
# 65533  318192  15432776  ZVA168    A+    91.0     NaN      NaN     69.0
#
#        Course_Att                                         MHRDName  ...  CA_3  \
# 65529        84.0  Bachelor of Technology (Mechanical Engineering)  ...   1.0
# 65530        80.0  Bachelor of Technology (Mechanical Engineering)  ...  10.0
# 65531        75.0  Bachelor of Technology (Mechanical Engineering)  ...  31.0
# 65532        80.0  Bachelor of Technology (Mechanical Engineering)  ...   1.0
# 65533        72.0  Bachelor of Technology (Mechanical Engineering)  ...   1.0
#
#        CA_4  Height  Weight  ScholarType  Direction  Gender Medium CourseType  \
# 65529  13.0     170      58  Day Scholar      South  Female  Hindi     Theory
# 65530  10.0     170      58  Day Scholar      South  Female  Hindi     Theory
# 65531   6.0     170      58  Day Scholar      South  Female  Hindi     Theory
# 65532   1.0     170      58  Day Scholar      South  Female  Hindi     Theory
# 65533   4.0     170      58  Day Scholar      South  Female  Hindi     Theory
#
#       ProgramType
# 65529          UG
# 65530          UG
# 65531          UG
# 65532          UG
# 65533          UG
#
# [5 rows x 22 columns]

# %% [markdown]
# # We created the New CSV file according to our datasets

# %%
import os
if os.path.isfile('My.csv'):
    print("not create again");
else:
    lst =  [['Termid','RegdNo','Course','Grade','CA_100','MTT_50','ETT_100','ETP_100','Course_Att','MHRDName','CA_1','CA_2','CA_3','CA_4','Height','Weight','ScholarType','Direction','Gender','Medium','CourseType','ProgramType']]
    d = pd.DataFrame(lst)
    for i in range(df.Termid.count()):
        if i == 0:
            d.to_csv('My.csv',mode='a',header=False)
        if df.MHRDName[i] == "Bachelor of Technology (Automobile Engineering)" :
            df.iloc[i:i+1,:].to_csv('My.csv',mode='a',header=False)
        else:
            pass
# Out:
# not create again

# %%
data = pd.read_csv('My.csv')

# %%
data = data.drop(["0"],axis=1)

# %%
data
# Out:
#      Termid    RegdNo   Course Grade  CA_100  MTT_50  ETT_100  ETP_100  \
# 0    218192   1128776   QPN110     O    90.0    37.0     93.0      NaN
# 1    218192   1128776   QPN111    A+    74.0     NaN      NaN     81.0
# 2    218192   1128776   QPN112     O    69.0    42.0     85.0      NaN
# 3    218192   1128776   QPN113     A    89.0    38.0     73.0      NaN
# 4    218192   1128776   QPN114    A+    97.0     NaN      NaN     82.0
# 5    218192   1128776   QPN115    A+    84.0    34.0     92.0      NaN
# 6    218192   1128776   QPN116     A    82.0    19.0     72.0      NaN
# 7    218192   1128776   QPN117    A+    85.0    48.0     75.0      NaN
# 8    218192   1128776   QPN118    B+    85.0    37.0     60.0      NaN
# 9    218192   1128776    QPN38     B    47.0    16.0     44.0      NaN
# 10   218192   1128776    QPN39     A    59.0     NaN      NaN     74.0
# 11   318192   1359776   QPN110    B+    72.0    40.0     53.0      NaN
# 12   318192   1359776   QPN111     A    61.0     NaN      NaN     69.0
# 13   318192   1359776   QPN112    A+    64.0    48.0     52.0      NaN
# 14   318192   1359776   QPN114     A    82.0     NaN      NaN     77.0
# 15   318192   1359776   QPN115     A    79.0    29.0     65.0      NaN
# 16   318192   1359776   QPN116    B+    80.0    22.0     50.0      NaN
# 17   318192   1359776    QPN31    A+    79.0    37.0     52.0      NaN
# 18   318192   1359776    QPN38     C    64.0    13.0     38.0      NaN
# 19   318192   1359776    QPN39     C    52.0     NaN      NaN     62.0
# 20   318192   1359776   QPN449    B+    74.0    29.0     63.0      NaN
# 21   318192   1359776   QPN450     A    77.0    34.0     33.0      NaN
# 22   318192   1416776   QPN110    B+    64.0    27.0     62.0      NaN
# 23   318192   1416776   QPN111     A    68.0     NaN      NaN     70.0
# 24   318192   1416776   QPN112     C    59.0    19.0     40.0      NaN
# 25   318192   1416776   QPN114    B+    81.0     NaN      NaN     58.0
# 26   318192   1416776   QPN115     C    54.0    25.0     48.0      NaN
# 27   318192   1416776   QPN116     E    70.0    13.0     26.0      NaN
# 28   318192   1416776   QPN206     A    67.0     NaN      NaN     77.0
# 29   318192   1416776    QPN38     C    46.0    15.0     47.0      NaN
# ..      ...       ...      ...   ...     ...     ...      ...      ...
# 547  118192  14809776   QPN397    B+    65.0    28.0     66.0      NaN
# 548  118192  14809776   QPN448     C    49.0    25.0     29.0      NaN
# 549  118192  14809776   QPN462     A    78.0     NaN      NaN     72.0
# 550  318192  14879776   QPN110    A+    80.0    44.0     82.0      NaN
# 551  318192  14879776   QPN111    A+    63.0     NaN      NaN     76.0
# 552  318192  14879776   QPN112    A+    49.0    30.0     65.0      NaN
# 553  318192  14879776   QPN113    A+    70.0    35.0     80.0      NaN
# 554  318192  14879776   QPN114    A+    85.0     NaN      NaN     78.0
# 555  318192  14879776   QPN115    A+    84.0    33.0     73.0      NaN
# 556  318192  14879776   QPN116     A    85.0    18.0     63.0      NaN
# 557  318192  14879776    QPN38    B+    64.0    17.0     49.0      NaN
# 558  318192  14879776    QPN39     A    58.0     NaN      NaN     74.0
# 559  318192  14879776   QPN596    A+    84.0     9.0     72.0      NaN
# 560  318192  14879776   QPN660    B+    82.0    28.0     58.0      NaN
# 561  318192  14925776    QPN11     B    83.0     NaN     36.0      NaN
# 562  318192  14925776  QPN1146    B+    75.0     NaN      NaN     67.0
# 563  318192  14925776     QPN8     D    52.0    17.0     32.0      NaN
# 564  318192  14925776     QPN9     A    70.0     NaN      NaN     61.0
# 565  418192  15045776    QPN11     B    64.0     NaN     50.0      NaN
# 566  418192  15045776  QPN1146     A    74.0     NaN      NaN     82.0
# 567  418192  15045776   QPN585     B    40.0    33.0     63.0      NaN
# 568  418192  15045776   QPN586    B+    81.0     NaN      NaN     52.0
# 569  218192  15242776  QPN1327     C    55.0     8.0     56.0      NaN
# 570  218192  15242776  QPN1328    B+    57.0    32.0     56.0      NaN
# 571  218192  15242776  QPN1329     C    44.0    22.0     50.0      NaN
# 572  218192  15242776  QPN1330     A    65.0    34.0     75.0      NaN
# 573  218192  15242776  QPN1331     O    87.0     NaN      NaN     92.0
# 574  218192  15242776  QPN1332    B+    95.0    17.0     62.0      NaN
# 575  218192  15242776    QPN28     A    60.0    34.0     75.0      NaN
# 576  218192  15242776   QPN328    B+    95.0    18.0     56.0      NaN
#
#      Course_Att                                         MHRDName  ...  CA_3  \
# 0          90.0  Bachelor of Technology (Automobile Engineering)  ...   0.0
# 1          87.0  Bachelor of Technology (Automobile Engineering)  ...   3.0
# 2          85.0  Bachelor of Technology (Automobile Engineering)  ...   9.0
# 3          83.0  Bachelor of Technology (Automobile Engineering)  ...   7.0
# 4          96.0  Bachelor of Technology (Automobile Engineering)  ...  26.0
# 5          86.0  Bachelor of Technology (Automobile Engineering)  ...  12.0
# 6          83.0  Bachelor of Technology (Automobile Engineering)  ...   4.0
# 7          84.0  Bachelor of Technology (Automobile Engineering)  ...  10.0
# 8          97.0  Bachelor of Technology (Automobile Engineering)  ...  44.0
# 9          86.0  Bachelor of Technology (Automobile Engineering)  ...   7.0
# 10         88.0  Bachelor of Technology (Automobile Engineering)  ...   3.0
# 11         85.0  Bachelor of Technology (Automobile Engineering)  ...   1.0
# 12         87.0  Bachelor of Technology (Automobile Engineering)  ...   3.0
# 13         82.0  Bachelor of Technology (Automobile Engineering)  ...   0.0
# 14         79.0  Bachelor of Technology (Automobile Engineering)  ...   4.0
# 15         81.0  Bachelor of Technology (Automobile Engineering)  ...  33.0
# 16         86.0  Bachelor of Technology (Automobile Engineering)  ...  16.0
# 17         77.0  Bachelor of Technology (Automobile Engineering)  ...   0.0
# 18         81.0  Bachelor of Technology (Automobile Engineering)  ...   5.0
# 19         73.0  Bachelor of Technology (Automobile Engineering)  ...   0.0
# 20         74.0  Bachelor of Technology (Automobile Engineering)  ...  11.0
# 21         87.0  Bachelor of Technology (Automobile Engineering)  ...   4.0
# 22         70.0  Bachelor of Technology (Automobile Engineering)  ...   6.0
# 23         68.0  Bachelor of Technology (Automobile Engineering)  ...  16.0
# 24         66.0  Bachelor of Technology (Automobile Engineering)  ...   1.0
# 25         78.0  Bachelor of Technology (Automobile Engineering)  ...  14.0
# 26         74.0  Bachelor of Technology (Automobile Engineering)  ...   7.0
# 27         85.0  Bachelor of Technology (Automobile Engineering)  ...   5.0
# 28         60.0  Bachelor of Technology (Automobile Engineering)  ...   3.0
# 29         83.0  Bachelor of Technology (Automobile Engineering)  ...   5.0
# ..          ...                                              ...  ...   ...
# 547        82.0  Bachelor of Technology (Automobile Engineering)  ...   1.0
# 548        91.0  Bachelor of Technology (Automobile Engineering)  ...   0.0
# 549        86.0  Bachelor of Technology (Automobile Engineering)  ...   8.0
# 550        98.0  Bachelor of Technology (Automobile Engineering)  ...   0.0
# 551       100.0  Bachelor of Technology (Automobile Engineering)  ...   1.0
# 552        95.0  Bachelor of Technology (Automobile Engineering)  ...  10.0
# 553        90.0  Bachelor of Technology (Automobile Engineering)  ...  10.0
# 554        96.0  Bachelor of Technology (Automobile Engineering)  ...  23.0
# 555        98.0  Bachelor of Technology (Automobile Engineering)  ...   0.0
# 556        94.0  Bachelor of Technology (Automobile Engineering)  ...  10.0
# 557        98.0  Bachelor of Technology (Automobile Engineering)  ...   1.0
# 558       100.0  Bachelor of Technology (Automobile Engineering)  ...   9.0
# 559        91.0  Bachelor of Technology (Automobile Engineering)  ...   0.0
# 560        95.0  Bachelor of Technology (Automobile Engineering)  ...   2.0
# 561        69.0  Bachelor of Technology (Automobile Engineering)  ...  18.0
# 562         NaN  Bachelor of Technology (Automobile Engineering)  ...   1.0
# 563        75.0  Bachelor of Technology (Automobile Engineering)  ...   1.0
# 564        86.0  Bachelor of Technology (Automobile Engineering)  ...   6.0
# 565        78.0  Bachelor of Technology (Automobile Engineering)  ...   2.0
# 566         NaN  Bachelor of Technology (Automobile Engineering)  ...  24.0
# 567        70.0  Bachelor of Technology (Automobile Engineering)  ...   5.0
# 568        79.0  Bachelor of Technology (Automobile Engineering)  ...   1.0
# 569        82.0  Bachelor of Technology (Automobile Engineering)  ...   2.0
# 570        91.0  Bachelor of Technology (Automobile Engineering)  ...   1.0
# 571        79.0  Bachelor of Technology (Automobile Engineering)  ...   5.0
# 572        85.0  Bachelor of Technology (Automobile Engineering)  ...   1.0
# 573        96.0  Bachelor of Technology (Automobile Engineering)  ...   0.0
# 574        80.0  Bachelor of Technology (Automobile Engineering)  ...   5.0
# 575        86.0  Bachelor of Technology (Automobile Engineering)  ...   2.0
# 576        84.0  Bachelor of Technology (Automobile Engineering)  ...  36.0
#
#      CA_4  Height  Weight  ScholarType  Direction  Gender    Medium  \
# 0     0.0     180      83      Hostler      South  Female  Regional
# 1     0.0     180      83      Hostler      South  Female  Regional
# 2     5.0     180      83      Hostler      South  Female  Regional
# 3    23.0     180      83      Hostler      South  Female  Regional
# 4     6.0     180      83      Hostler      South  Female  Regional
# 5    23.0     180      83      Hostler      South  Female  Regional
# 6    24.0     180      83      Hostler      South  Female  Regional
# 7     9.0     180      83      Hostler      South  Female  Regional
# 8    21.0     180      83      Hostler      South  Female  Regional
# 9     3.0     180      83      Hostler      South  Female  Regional
# 10    8.0     180      83      Hostler      South  Female  Regional
# 11    4.0     150      67      Hostler       West  Female     Hindi
# 12    0.0     150      67      Hostler       West  Female     Hindi
# 13    0.0     150      67      Hostler       West  Female     Hindi
# 14   15.0     150      67      Hostler       West  Female     Hindi
# 15   12.0     150      67      Hostler       West  Female     Hindi
# 16    9.0     150      67      Hostler       West  Female     Hindi
# 17    0.0     150      67      Hostler       West  Female     Hindi
# 18    7.0     150      67      Hostler       West  Female     Hindi
# 19    0.0     150      67      Hostler       West  Female     Hindi
# 20   17.0     150      67      Hostler       West  Female     Hindi
# 21   17.0     150      67      Hostler       West  Female     Hindi
# 22   20.0     150      88      Hostler       West    Male     Hindi
# 23   15.0     150      88      Hostler       West    Male     Hindi
# 24    2.0     150      88      Hostler       West    Male     Hindi
# 25    0.0     150      88      Hostler       West    Male     Hindi
# 26    8.0     150      88      Hostler       West    Male     Hindi
# 27    0.0     150      88      Hostler       West    Male     Hindi
# 28    5.0     150      88      Hostler       West    Male     Hindi
# 29    2.0     150      88      Hostler       West    Male     Hindi
# ..    ...     ...     ...          ...        ...     ...       ...
# 547   5.0     155      45  Day Scholar      North    Male  Regional
# 548   1.0     155      45  Day Scholar      North    Male  Regional
# 549   5.0     155      45  Day Scholar      North    Male  Regional
# 550   1.0     169      84  Day Scholar       West  Female  Regional
# 551   0.0     169      84  Day Scholar       West  Female  Regional
# 552   1.0     169      84  Day Scholar       West  Female  Regional
# 553  10.0     169      84  Day Scholar       West  Female  Regional
# 554  34.0     169      84  Day Scholar       West  Female  Regional
# 555   0.0     169      84  Day Scholar       West  Female  Regional
# 556   4.0     169      84  Day Scholar       West  Female  Regional
# 557   8.0     169      84  Day Scholar       West  Female  Regional
# 558   7.0     169      84  Day Scholar       West  Female  Regional
# 559   0.0     169      84  Day Scholar       West  Female  Regional
# 560  61.0     169      84  Day Scholar       West  Female  Regional
# 561  13.0     180      97  Day Scholar      South  Female   English
# 562  12.0     180      97  Day Scholar      South  Female   English
# 563   0.0     180      97  Day Scholar      South  Female   English
# 564   8.0     180      97  Day Scholar      South  Female   English
# 565   3.0     163      51      Hostler      North  Female  Regional
# 566   0.0     163      51      Hostler      North  Female  Regional
# 567   0.0     163      51      Hostler      North  Female  Regional
# 568   0.0     163      51      Hostler      North  Female  Regional
# 569  32.0     161      47  Day Scholar      North  Female  Regional
# 570   9.0     161      47  Day Scholar      North  Female  Regional
# 571   0.0     161      47  Day Scholar      North  Female  Regional
# 572  19.0     161      47  Day Scholar      North  Female  Regional
# 573   0.0     161      47  Day Scholar      North  Female  Regional
# 574   1.0     161      47  Day Scholar      North  Female  Regional
# 575   1.0     161      47  Day Scholar      North  Female  Regional
# 576   6.0     161      47  Day Scholar      North  Female  Regional
#
#     CourseType ProgramType
# 0       Theory          UG
# 1       Theory          UG
# 2       Theory          UG
# 3       Theory          UG
# 4       Theory          UG
# 5       Theory          UG
# 6       Theory          UG
# 7       Theory          UG
# 8       Theory          UG
# 9       Theory          UG
# 10      Theory          UG
# 11      Theory          UG
# 12      Theory          UG
# 13      Theory          UG
# 14      Theory          UG
# 15      Theory          UG
# 16      Theory          UG
# 17      Theory          UG
# 18      Theory          UG
# 19      Theory          UG
# 20      Theory          UG
# 21      Theory          UG
# 22      Theory          UG
# 23      Theory          UG
# 24      Theory          UG
# 25      Theory          UG
# 26      Theory          UG
# 27      Theory          UG
# 28      Theory          UG
# 29      Theory          UG
# ..         ...         ...
# 547     Theory          UG
# 548     Theory          UG
# 549     Theory          UG
# 550     Theory          UG
# 551     Theory          UG
# 552     Theory          UG
# 553     Theory          UG
# 554     Theory          UG
# 555     Theory          UG
# 556     Theory          UG
# 557     Theory          UG
# 558     Theory          UG
# 559     Theory          UG
# 560     Theory          UG
# 561     Theory          UG
# 562     Theory          UG
# 563     Theory          UG
# 564     Theory          UG
# 565     Theory          UG
# 566     Theory          UG
# 567     Theory          UG
# 568     Theory          UG
# 569     Theory          UG
# 570     Theory          UG
# 571     Theory          UG
# 572     Theory          UG
# 573     Theory          UG
# 574     Theory          UG
# 575     Theory          UG
# 576     Theory          UG
#
# [577 rows x 22 columns]

# %%
X = data.iloc[:,4:8].values
X
# Out:
# array([[90., 37., 93., nan],
#        [74., nan, nan, 81.],
#        [69., 42., 85., nan],
#        ...,
#        [95., 17., 62., nan],
#        [60., 34., 75., nan],
#        [95., 18., 56., nan]])

# %%
## WE have Null values SO we have to fix it By using Imputer from the SKlearn.Preprocessing

# %% [markdown]
# # Lets Start Preprocessing

# %%
from sklearn.preprocessing import Imputer

# %%
imputer = Imputer(missing_values='NaN',strategy='mean',axis=0)
imputer.fit(X)
X = imputer.transform(X)
X
# Out:
# /Users/abhishek/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# array([[90.        , 37.        , 93.        , 70.92045455],
#        [74.        , 25.95212766, 53.75561097, 81.        ],
#        [69.        , 42.        , 85.        , 70.92045455],
#        ...,
#        [95.        , 17.        , 62.        , 70.92045455],
#        [60.        , 34.        , 75.        , 70.92045455],
#        [95.        , 18.        , 56.        , 70.92045455]])

# %%
# Out:
# /Users/abhishek/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5097                 else:
# -> 5098                     object.__setattr__(self, name, value)
#    5099             except (AttributeError, TypeError):
#
# AttributeError: can't set attribute
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-104-afd17c044015> in <module>
# ----> 1 data.iloc[:,4:8].values = X
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5104                                   "stable/indexing.html#attribute-access",
#    5105                                   stacklevel=2)
# -> 5106                 object.__setattr__(self, name, value)
#    5107
#    5108     def _dir_additions(self):
#
# AttributeError: can't set attribute
